# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load your dataset
df = pd.read_csv(r"C:\Users\Admin\Desktop\ASIYA_PROJECTS\AI_DECENTRALIZATION_INTERNSHIP\Visualization_task\archive (2)\diabetes.csv")
display(df.head())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x="Outcome", data=df)
plt.title("Count of Diabetic vs Non-Diabetic")
plt.xlabel("Outcome (0=No Diabetes, 1=Diabetes)")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x="Outcome", y="Glucose", data=df)
plt.title("Glucose Levels by Diabetes Outcome")
plt.xlabel("Outcome (0=No Diabetes, 1=Diabetes)")
plt.ylabel("Glucose Level")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.violinplot(x="Outcome", y="BMI", data=df, inner="quartile")
plt.title("BMI Distribution by Diabetes Outcome")
plt.xlabel("Outcome (0=No Diabetes, 1=Diabetes)")
plt.ylabel("BMI")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(data=df, x="Age", hue="Outcome", fill=True)
plt.title("Age Distribution by Diabetes Outcome")
plt.xlabel("Age")
plt.ylabel("Density")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.swarmplot(x="Outcome", y="BloodPressure", data=df, size=3)
plt.title("Blood Pressure Distribution by Outcome")
plt.xlabel("Outcome (0=No Diabetes, 1=Diabetes)")
plt.ylabel("Blood Pressure")
plt.show()
